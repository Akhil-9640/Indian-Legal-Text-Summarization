# %% [markdown]
# ### Script to chunk and save every file. Every line in the output file is a chunk.

# %%
dataset = "IN" # Options: IN - IN-Abs, UK-UK-Abs, N2-IN-Ext 
output_path = "./output/"

# %%
import pandas as pd
import numpy as np
import glob
import os
import nltk
import sys
sys.path.insert(0, '../')
from utilities import *
names, data_source, data_summary = get_summary_data(dataset, "test")
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "C:\Users\akhhe\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\akhhe\AppData\Local\Temp\ipykernel_6088\887901358.py", line 5, in <module>
#     import nltk
#   File "C:\Users\akhhe\AppData\Roaming\Python\Python39\site-packages\nltk\__init__.py", line 146, in <module>
#     from nltk.chunk import *
#   File "C:\Users\akhhe\AppData\Roaming\Python\Python39\site-packages\nltk\chunk\__init__.py", line 155, in <module>
#     from nltk.chunk.api import ChunkParserI
#   File "C:\Users\akhhe\AppData\Roaming\Python\Python39\site-packages\nltk\chunk\api.py", line 15, in <module>
#     from nltk.parse import ParserI
#   File "C:\Users\akhhe\AppData\Roaming\Python\Python39\site-packages\nltk\parse\__init__.py", line 100, in <module>
#     from nltk.parse.transitionparser import TransitionParser
#   File "C:\Users\akhhe\AppData\Roaming\Python\Python39\site-packages\nltk\parse\transitionparser.py", line 19, in <module>
#     from sklearn.datasets import load_svmlight_file
#   File "C:\Users\akhhe\anaconda3\lib\site-packages\sklearn\datasets\__init__.py", line 48, in <module>
#     from ._olivetti_faces import fetch_olivetti_faces
#   File "C:\Users\akhhe\anaconda3\lib\site-packages\sklearn\datasets\_olivetti_faces.py", line 20, in <module>
#     from scipy.io.matlab import loadmat
#   File "C:\Users\akhhe\anaconda3\lib\site-packages\scipy\io\__init__.py", line 98, in <module>
#     from .matlab import loadmat, savemat, whosmat
#   File "C:\Users\akhhe\anaconda3\lib\site-packages\scipy\io\matlab\__init__.py", line 45, in <module>
#     from ._mio import loadmat, savemat, whosmat
#   File "C:\Users\akhhe\anaconda3\lib\site-packages\scipy\io\matlab\_mio.py", line 9, in <module>
#     from ._mio4 import MatFile4Reader, MatFile4Writer
#   File "C:\Users\akhhe\anaconda3\lib\site-packages\scipy\io\matlab\_mio4.py", line 13, in <module>
#     from ._mio_utils import squeeze_element, chars_to_strings
#   File "<frozen importlib._bootstrap>", line 398, in parent
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\akhhe\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\akhhe\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "C:\Users\akhhe\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "C:\Users\akhhe\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "C:\Users\akhhe\anaconda3\lib\inspect.py", line 1543, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "C:\Users\akhhe\anaconda3\lib\inspect.py", line 1501, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "C:\Users\akhhe\anaconda3\lib\inspect.py", line 709, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "C:\Users\akhhe\anaconda3\lib\inspect.py", line 755, in getmodule
#     os.path.realpath(f)] = module.__name__
#   File "C:\Users\akhhe\anaconda3\lib\ntpath.py", line 647, in realpath
#     path = _getfinalpathname(path)
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "C:\Users\akhhe\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\akhhe\AppData\Local\Temp\ipykernel_6088\887901358.py", line 5, in <module>
#     import nltk
#   File "C:\Users\akhhe\AppData\Roaming\Python\Python39\site-packages\nltk\__init__.py", line 146, in <module>
#     from nltk.chunk import *
#   File "C:\Users\akhhe\AppData\Roaming\Python\Python39\site-packages\nltk\chunk\__init__.py", line 155, in <module>
#     from nltk.chunk.api import ChunkParserI
#   File "C:\Users\akhhe\AppData\Roaming\Python\Python39\site-packages\nltk\chunk\api.py", line 15, in <module>
#     from nltk.parse import ParserI
#   File "C:\Users\akhhe\AppData\Roaming\Python\Python39\site-packages\nltk\parse\__init__.py", line 100, in <module>
#     from nltk.parse.transitionparser import TransitionParser
#   File "C:\Users\akhhe\AppData\Roaming\Python\Python39\site-packages\nltk\parse\transitionparser.py", line 19, in <module>
#     from sklearn.datasets import load_svmlight_file
#   File "C:\Users\akhhe\anaconda3\lib\site-packages\sklearn\datasets\__init__.py", line 48, in <module>
#     from ._olivetti_faces import fetch_olivetti_faces
#   File "C:\Users\akhhe\anaconda3\lib\site-packages\sklearn\datasets\_olivetti_faces.py", line 20, in <module>
#     from scipy.io.matlab import loadmat
#   File "C:\Users\akhhe\anaconda3\lib\site-packages\scipy\io\__init__.py", line 98, in <module>
#     from .matlab import loadmat, savemat, whosmat
#   File "C:\Users\akhhe\anaconda3\lib\site-packages\scipy\io\matlab\__init__.py", line 45, in <module>
#     from ._mio import loadmat, savemat, whosmat
#   File "C:\Users\akhhe\anaconda3\lib\site-packages\scipy\io\matlab\_mio.py", line 9, in <module>
#     from ._mio4 import MatFile4Reader, MatFile4Writer
#   File "C:\Users\akhhe\anaconda3\lib\site-packages\scipy\io\matlab\_mio4.py", line 13, in <module>
#     from ._mio_utils import squeeze_element, chars_to_strings
#   File "<frozen importlib._bootstrap>", line 398, in parent
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\akhhe\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\akhhe\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3377, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "C:\Users\akhhe\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3474, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "C:\Users\akhhe\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2079, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "C:\Users\akhhe\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "C:\Users\akhhe\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "C:\Users\akhhe\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "C:\Users\akhhe\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "C:\Users\akhhe\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\akhhe\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\akhhe\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "C:\Users\akhhe\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "C:\Users\akhhe\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "C:\Users\akhhe\anaconda3\lib\inspect.py", line 1543, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "C:\Users\akhhe\anaconda3\lib\inspect.py", line 1501, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "C:\Users\akhhe\anaconda3\lib\inspect.py", line 709, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "C:\Users\akhhe\anaconda3\lib\inspect.py", line 755, in getmodule
#     os.path.realpath(f)] = module.__name__
#   File "C:\Users\akhhe\anaconda3\lib\ntpath.py", line 647, in realpath
#     path = _getfinalpathname(path)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# ~\AppData\Local\Temp\ipykernel_6088\887901358.py in <module>
#       4 import os
# ----> 5 import nltk
#       6 import sys
#
# ~\AppData\Roaming\Python\Python39\site-packages\nltk\__init__.py in <module>
#     145
# --> 146 from nltk.chunk import *
#     147 from nltk.classify import *
#
# ~\AppData\Roaming\Python\Python39\site-packages\nltk\chunk\__init__.py in <module>
#     154
# --> 155 from nltk.chunk.api import ChunkParserI
#     156 from nltk.chunk.regexp import RegexpChunkParser, RegexpParser
#
# ~\AppData\Roaming\Python\Python39\site-packages\nltk\chunk\api.py in <module>
#      14 from nltk.internals import deprecated
# ---> 15 from nltk.parse import ParserI
#      16
#
# ~\AppData\Roaming\Python\Python39\site-packages\nltk\parse\__init__.py in <module>
#      99 from nltk.parse.shiftreduce import ShiftReduceParser, SteppingShiftReduceParser
# --> 100 from nltk.parse.transitionparser import TransitionParser
#     101 from nltk.parse.util import TestGrammar, extract_test_sentences, load_parser
#
# ~\AppData\Roaming\Python\Python39\site-packages\nltk\parse\transitionparser.py in <module>
#      18     from sklearn import svm
# ---> 19     from sklearn.datasets import load_svmlight_file
#      20 except ImportError:
#
# ~\anaconda3\lib\site-packages\sklearn\datasets\__init__.py in <module>
#      47 from ._svmlight_format_io import dump_svmlight_file
# ---> 48 from ._olivetti_faces import fetch_olivetti_faces
#      49 from ._species_distributions import fetch_species_distributions
#
# ~\anaconda3\lib\site-packages\sklearn\datasets\_olivetti_faces.py in <module>
#      19 import numpy as np
# ---> 20 from scipy.io.matlab import loadmat
#      21 import joblib
#
# ~\anaconda3\lib\site-packages\scipy\io\__init__.py in <module>
#      97 # matfile read and write
# ---> 98 from .matlab import loadmat, savemat, whosmat
#      99
#
# ~\anaconda3\lib\site-packages\scipy\io\matlab\__init__.py in <module>
#      44 # Matlab file read and write utilities
# ---> 45 from ._mio import loadmat, savemat, whosmat
#      46 from ._mio5 import MatlabFunction
#
# ~\anaconda3\lib\site-packages\scipy\io\matlab\_mio.py in <module>
#       8 from ._miobase import _get_matfile_version, docfiller
# ----> 9 from ._mio4 import MatFile4Reader, MatFile4Writer
#      10 from ._mio5 import MatFile5Reader, MatFile5Writer
#
# ~\anaconda3\lib\site-packages\scipy\io\matlab\_mio4.py in <module>
#      12
# ---> 13 from ._mio_utils import squeeze_element, chars_to_strings
#      14 from functools import reduce
#
# ~\anaconda3\lib\importlib\_bootstrap.py in parent(self)
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\IPython\core\interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2076                         # in the engines. This should return a list of strings.
# -> 2077                         stb = value._render_traceback_()
#    2078                     except Exception:
#
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_ast_nodes(self, nodelist, cell_name, interactivity, compiler, result)
#    3376                         asy = compare(code)
# -> 3377                     if (await self.run_code(code, result,  async_=asy)):
#    3378                         return True
#
#     [... skipping hidden 1 frame]
#
# ~\anaconda3\lib\site-packages\IPython\core\interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2078                     except Exception:
# -> 2079                         stb = self.InteractiveTB.structured_traceback(etype,
#    2080                                             value, tb, tb_offset=tb_offset)
#
# ~\anaconda3\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1366             self.tb = tb
# -> 1367         return FormattedTB.structured_traceback(
#    1368             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#
# ~\anaconda3\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1266             # Verbose modes need a full traceback
# -> 1267             return VerboseTB.structured_traceback(
#    1268                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#
# ~\anaconda3\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1123
# -> 1124         formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#    1125                                                                tb_offset)
#
# ~\anaconda3\lib\site-packages\IPython\core\ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1081
# -> 1082         last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#    1083
#
# ~\anaconda3\lib\site-packages\IPython\core\ultratb.py in find_recursion(etype, value, records)
#     381     if not is_recursion_error(etype, value, records):
# --> 382         return len(records), 0
#     383
#
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\IPython\core\interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2076                         # in the engines. This should return a list of strings.
# -> 2077                         stb = value._render_traceback_()
#    2078                     except Exception:
#
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\IPython\core\async_helpers.py in _pseudo_sync_runner(coro)
#      76     """
#      77     try:
# ---> 78         coro.send(None)
#      79     except StopIteration as exc:
#      80         return exc.value
#
# ~\anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_cell_async(self, raw_cell, store_history, silent, shell_futures, transformed_cell, preprocessing_exc_tuple)
#    3183                     interactivity = 'async'
#    3184
# -> 3185                 has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    3186                        interactivity=interactivity, compiler=compiler, result=result)
#    3187
#
# ~\anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_ast_nodes(self, nodelist, cell_name, interactivity, compiler, result)
#    3394             if result:
#    3395                 result.error_before_exec = sys.exc_info()[1]
# -> 3396             self.showtraceback()
#    3397             return True
#    3398
#
# ~\anaconda3\lib\site-packages\IPython\core\interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2077                         stb = value._render_traceback_()
#    2078                     except Exception:
# -> 2079                         stb = self.InteractiveTB.structured_traceback(etype,
#    2080                                             value, tb, tb_offset=tb_offset)
#    2081
#
# ~\anaconda3\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1365         else:
#    1366             self.tb = tb
# -> 1367         return FormattedTB.structured_traceback(
#    1368             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1369
#
# ~\anaconda3\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1265         if mode in self.verbose_modes:
#    1266             # Verbose modes need a full traceback
# -> 1267             return VerboseTB.structured_traceback(
#    1268                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1269             )
#
# ~\anaconda3\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1140         chained_exc_ids = set()
#    1141         while evalue:
# -> 1142             formatted_exceptions += self.format_exception_as_a_whole(etype, evalue, etb, lines_of_context,
#    1143                                                                      chained_exceptions_tb_offset)
#    1144             exception = self.get_parts_of_chained_exception(evalue)
#
# ~\anaconda3\lib\site-packages\IPython\core\ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1080
#    1081
# -> 1082         last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#    1083
#    1084         frames = self.format_records(records, last_unique, recursion_repeat)
#
# ~\anaconda3\lib\site-packages\IPython\core\ultratb.py in find_recursion(etype, value, records)
#     380     # first frame (from in to out) that looks different.
#     381     if not is_recursion_error(etype, value, records):
# --> 382         return len(records), 0
#     383
#     384     # Select filename, lineno, func_name to track frames with
#
# TypeError: object of type 'NoneType' has no len()

# %%
import os
if not os.path.exists(output_path + './'+ dataset +'_chunked/'):
    os.makedirs(output_path + './'+ dataset +'_chunked/')

# %%
for i in range(len(data_source)):
    doc = data_source[i].replace("\n", " ")
    chunks = nest_sentences(doc, 512)
    save = "\n".join(chunks)
    path = output_path +  "./"+ dataset +"_chunked/" + names[i]
    file = open(path,'w')
    file.write(save)
    file.close()
#     break
